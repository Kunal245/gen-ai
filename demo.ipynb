# %%
print("hello")
# Out:
# hello

# %%
pip install langchain
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/558.3 kB ? eta -:--:--
#    ---------------------------------------- 0.0/558.3 kB ? eta -:--:--
#    ---------------------------------------- 0.0/558.3 kB ? eta -:--:--
#    ------------------ --------------------- 262.1/558.3 kB ? eta -:--:--
#    ------------------ --------------------- 262.1/558.3 kB ? eta -:--:--
#    ---------------------------------------- 558.3/558.3 kB 631.4 kB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/652.5 kB ? eta -:--:--
#    ---------------------------------------- 0.0/652.5 kB ? eta -:--:--
#    ---------------------------------------- 0.0/652.5 kB ? eta -:--:--
#    ---------------------------------------- 0.0/652.5 kB ? eta -:--:--
#    ---------------------------------------- 0.0/652.5 kB ? eta -:--:--
#    ---------------------------------------- 0.0/652.5 kB ? eta -:--:--
# ...
